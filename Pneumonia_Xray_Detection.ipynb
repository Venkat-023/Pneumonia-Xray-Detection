# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("paultimothymooney/chest-xray-pneumonia")

print("Path to dataset files:", path)

# %%
# !kaggle datasets download paultimothymooney/chest-xray-pneumonia
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# Downloading chest-xray-pneumonia.zip to /content
#  99% 2.27G/2.29G [00:34<00:00, 56.3MB/s]
# 100% 2.29G/2.29G [00:34<00:00, 71.4MB/s]

# %%
import zipfile
zip_ref=zipfile.ZipFile('/content/chest-xray-pneumonia.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
import keras

# %%
train_ds=keras.utils.image_dataset_from_directory(
    directory='/content/chest_xray/train'
    ,labels='inferred'
    ,label_mode='int'
    ,batch_size=64
    ,image_size=(256,256)
)
test_ds=keras.utils.image_dataset_from_directory(
    directory="/content/chest_xray/test",
    labels="inferred",
    label_mode="int",
    batch_size=64,
    image_size=(256,256)
)
# Out:
# Found 5216 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
def resize(image,label):
  image=tf.cast(image/255.0,tf.float32)
  return image,label
train_ds=train_ds.map(resize)
test_ds=test_ds.map(resize)

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,1)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(train_ds,epochs=10,validation_data=train_ds)
# Out:
# Epoch 1/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 828ms/step - accuracy: 0.7905 - loss: 0.5327 - val_accuracy: 0.9231 - val_loss: 0.1821
# Epoch 2/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 75s 878ms/step - accuracy: 0.9512 - loss: 0.1234 - val_accuracy: 0.9605 - val_loss: 0.1042
# Epoch 3/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 746ms/step - accuracy: 0.9752 - loss: 0.0739 - val_accuracy: 0.9801 - val_loss: 0.0610
# Epoch 4/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 732ms/step - accuracy: 0.9774 - loss: 0.0593 - val_accuracy: 0.9808 - val_loss: 0.0571
# Epoch 5/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 60s 740ms/step - accuracy: 0.9734 - loss: 0.0667 - val_accuracy: 0.9864 - val_loss: 0.0407
# Epoch 6/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 93s 882ms/step - accuracy: 0.9843 - loss: 0.0396 - val_accuracy: 0.9939 - val_loss: 0.0176
# Epoch 7/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 71s 875ms/step - accuracy: 0.9907 - loss: 0.0273 - val_accuracy: 0.9973 - val_loss: 0.0076
# Epoch 8/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 742ms/step - accuracy: 0.9928 - loss: 0.0158 - val_accuracy: 0.9987 - val_loss: 0.0045
# Epoch 9/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 741ms/step - accuracy: 0.9944 - loss: 0.0162 - val_accuracy: 0.9975 - val_loss: 0.0082
# Epoch 10/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 743ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.9990 - val_loss: 0.0030
